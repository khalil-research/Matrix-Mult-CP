# %%
# !pip install cplex
# !pip install docplex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cplex in /usr/local/lib/python3.9/dist-packages (22.1.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: docplex in /usr/local/lib/python3.9/dist-packages (2.25.236)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from docplex) (1.15.0)

# %%
# !pip install gurobipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gurobipy in /usr/local/lib/python3.9/dist-packages (10.0.1)

# %%
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import pandas as pd
from docplex.cp.model import CpoModel
import numpy as np

# %% [markdown]
# # Function to get Multiplication Tensor $T_n$

# %%
# Implementation for square matrices
def multiplication_tensor(N=2):
    """Multiplication tensor.
    The multiplication tensor T of order N is defined by:
        C == A @ B <=> vec(C) == T x1 vec(A.T) x2 vec(B.T)
    where A, B, and C are N x N matrices and vec is the column-wise
    vectorization operator.
    """
    T = np.zeros((N ** 2, N ** 2, N ** 2), dtype=np.int64)
    for n in range(N):
        for m in range(N):
            u = np.ravel_multi_index(
                (n * np.ones(N, dtype=np.int64), np.arange(N)), (N, N))
            v = np.ravel_multi_index(
                (np.arange(N), m * np.ones(N, dtype=np.int64)), (N, N))
            w = np.ravel_multi_index(
                (m, n), (N, N)) * np.ones(len(u), dtype=np.int64)
            
            T[u, v, w] = 1
    # Assert cyclic symmetry.
    assert np.all(T == np.transpose(T, [2, 0, 1]))
    assert np.all(T == np.transpose(T, [1, 2, 0]))
    
    return T

# %%
# Implementation for square and non-square matrices
def general_multiplication_tensor(M, P, N):
   """Multiplication tensor.
   The multiplication tensor T in {0,1} of size MP x PN x MN
   for the multiplication of two matrices of size MxP and PxN
   """
   T = np.zeros((M * P, P * N, M * N), dtype=np.int64)

   for m in range(M):
       for p in range(P):
           for n in range(N):
               # Convert multi-dimensional indices to flat indices.
               a_index = np.ravel_multi_index((m, p), (M, P))
               b_index = np.ravel_multi_index((p, n), (P, N))
               c_index = np.ravel_multi_index((m, n), (M, N))
               T[a_index, b_index, c_index] = 1

   # Assert cyclic symmetry.
   #assert np.all(T == np.transpose(T, [2, 0, 1]))
   #assert np.all(T == np.transpose(T, [1, 2, 0]))

   return T

# %% [markdown]
# # Constraint Programming Formulations

# %% [markdown]
# ### Simple square CP formulation

# %%
def CP(n,T,R):
    mdl = CpoModel()
    U = [[mdl.integer_var(-1, 1, name="U" + str(n) + "_" + str(r)) for r in range(R)] for n in range(n**2)]
    V = [[mdl.integer_var(-1, 1, name="V" + str(n) + "_" + str(r)) for r in range(R)] for n in range(n**2)]
    W = [[mdl.integer_var(-1, 1, name="W" + str(n) + "_" + str(r)) for r in range(R)] for n in range(n**2)]
    for i in range(n**2):
        for j in range(n**2):
            for k in range(n**2):
                mdl.add(mdl.sum(U[i][r]*V[j][r]*W[k][r] for r in range(R)) == T[i][j][k])
    msol = mdl.solve()
    if msol:
      return [msol,U,V,W]
    else:
      print("Infeasible")
      return -1

# %% [markdown]
# ## Cyclic Invariant square CP formulation

# %%
def Cp_opt_cyclic(n,T_n,S,R):
    T = int((R-S)/3)
    print(T)
  
    mdl = CpoModel()
    A = [[mdl.integer_var(-1, 1, name="A" + str(n) + "_" + str(r)) for r in range(S)] for n in range(n**2)]
    B = [[mdl.integer_var(-1, 1, name="B" + str(n) + "_" + str(r)) for r in range(T)] for n in range(n**2)]
    C = [[mdl.integer_var(-1, 1, name="C" + str(n) + "_" + str(r)) for r in range(T)] for n in range(n**2)]
    D = [[mdl.integer_var(-1, 1, name="D" + str(n) + "_" + str(r)) for r in range(T)] for n in range(n**2)]
    
    for i in range(n**2):
        for j in range(n**2):
            for k in range(n**2):
              r_sum = []
              for r in range(R):
                if r <=S-1:
                 
                  r_sum.append(A[i][r]*A[j][r]*A[k][r])
                elif r>=S and r<=S-1+T:

                    r_sum.append(B[i][r-S]*D[j][r-S]*C[k][r-S])
                elif r>S-2+T and r<=S-1+2*T:
                     r_sum.append(C[i][r-S-T]*B[j][r-S-T]*D[k][r-S-T])
                else:
                  r_sum.append(D[i][r-S-2*T]*C[j][r-S-2*T]*B[k][r-S-2*T])

              mdl.add(mdl.sum(r_sum) == T_n[i][j][k])

              #mdl.add(mdl.sum(A[i][r]*A[i][r]*A[i][r] for r in range(S)) + mdl.sum(U[i][r]*V[j][r]*W[k][r] for r in range(R)) == T[i][j][k])
    msol = mdl.solve()
    if msol:
      return [msol,A,B,C,D]
    else:
      print("Infeasible")
      return -1

# %% [markdown]
# # Simple CP formulation for general matrix multiplication

# %%
def CP_general(M,P,N,T,R):
    mdl = CpoModel()
    U = [[mdl.integer_var(-1, 1, name="U" + str(n) + "_" + str(r)) for r in range(R)] for n in range(M*P)]
    V = [[mdl.integer_var(-1, 1, name="V" + str(n) + "_" + str(r)) for r in range(R)] for n in range(P*N)]
    W = [[mdl.integer_var(-1, 1, name="W" + str(n) + "_" + str(r)) for r in range(R)] for n in range(M*N)]
    for i in range(M*P):
        for j in range(P*N):
            for k in range(M*N):
                mdl.add(mdl.sum(U[i][r]*V[j][r]*W[k][r] for r in range(R)) == T[i][j][k])
    msol = mdl.solve()
    if msol:
      return [msol,U,V,W]
    else:
      print("Infeasible")
      return -1

# %% [markdown]
# # Function to retrieve $T_n$ given rank 1 decomposition matrices U,V,W

# %%
def expand_pd(U, V, W):
    """Expand a polyadic decomposition.
    The polyadic expansion T of the factor matrices U, V, and W is defined by:
        T[i, j, k] = \sum_r U[i, r] * V[j, r] * W[k, r].
    """
    I, J, K, R = U.shape[0], V.shape[0], W.shape[0], U.shape[1]
    T = np.zeros((I, J, K))
    for i in range(I):
        for j in range(J):
            for k in range(K):
                for r in range(R):
                    T[i, j, k] += U[i, r] * V[j, r] * W[k, r]
    return T

# %% [markdown]
# # Test our Implementations

# %% [markdown]
# #### Implementation 1 --> simplest CP formulation for square matrices

# %%
N = 2
R = 7
T = multiplication_tensor(N)
solution = CP(N,T,R)

if type(solution)!=int:
  sol,U,V,W = solution
else:
  print("Infeasible")

U_sol = np.zeros((N**2,R))
V_sol = np.zeros((N**2,R))
W_sol = np.zeros((N**2,R))

for i in range(N**2):
  for r in range(R):
    U_sol[i,r] = sol[U[i][r]]
    V_sol[i,r] = sol[V[i][r]]
    W_sol[i,r] = sol[W[i][r]]

print("\n\n\n\n\n\n")
t_constraint_programming = expand_pd(U_sol, V_sol, W_sol)
if (t_constraint_programming==T).all():
  print("Holy **** CP got the correct T_n")

# %% [markdown]
# #### Implementation 2 --> cyclic invariant CP formulation for square matrices

# %%
# simples 2 by 2 square case --> rank = 7 for strassen's solution
# there are only two working S for 2 by 2 it is S = 1 and S = 4

N = 2
R = 7
S = 1
T = int((R-S)/3)
T_n = multiplication_tensor(N)
solution = Cp_opt_cyclic(N,T_n,S,R)

if type(solution)!=int:
  sol,A,B,C,D= solution
else:
  print("Infeasible")

A_sol = np.zeros((N**2,S))
B_sol = np.zeros((N**2,T))
C_sol = np.zeros((N**2,T))
D_sol = np.zeros((N**2,T))

for i in range(N**2):
  for r in range(S):
    A_sol[i,r] = sol[A[i][r]]
  for r in range(T):
    B_sol[i,r] = sol[B[i][r]]
    C_sol[i,r] = sol[C[i][r]]
    D_sol[i,r] = sol[D[i][r]]


U_sol = np.hstack((A_sol, B_sol, C_sol, D_sol))
V_sol = np.hstack((A_sol, D_sol, B_sol, C_sol))
W_sol = np.hstack((A_sol, C_sol, D_sol, B_sol))
print("\n\n\n\n\n\n")
t_constraint_programming = expand_pd(U_sol, V_sol, W_sol)
if (t_constraint_programming==T_n).all():
  print("Holy **** CP got the correct T_n using cyclic invariance constraints")

# %% [markdown]
# # Now let us check our implementations for non-square matrix multiplications

# %%
M = 2
P = 3
N = 2
T_n = general_multiplication_tensor(M, P, N)

R = 11

solution = CP_general(M,P,N,T_n,R)

if type(solution)!=int:
  sol,U,V,W = solution
else:
  print("Infeasible")

U_sol = np.zeros((M*P,R))
V_sol = np.zeros((P*N,R))
W_sol = np.zeros((M*N,R))

for i in range(M*P):
  for r in range(R):
    U_sol[i,r] = sol[U[i][r]]
for i in range(N*P):
  for r in range(R):
    V_sol[i,r] = sol[V[i][r]]
for i in range(M*N):
  for r in range(R):
    W_sol[i,r] = sol[W[i][r]]

print("\n\n\n\n\n\n")
t_constraint_programming = expand_pd(U_sol, V_sol, W_sol)
if (t_constraint_programming==T_n).all():
  print("Holy **** CP got the correct T_n for non square matrices")
# Out:
# Streaming output truncated to the last 5000 lines.
#                     1779k         35    1   F     1  = V4_2
#                     1786k         62    2   F     1  = V2_10
#                     1780k         68    1         0  = U2_6
#                     1787k         40    2   F     1  = V1_8
#                     1781k         45    1         0  = V2_2
#                     1788k         44    2   F    -1 != W1_10
#                     1789k         41    2         0  = U3_9
#                     1782k         10    1        -1 != V0_7
#                     1790k         41    2         1 != V2_8
#                     1783k         62    1   F     1  = U2_6
#                     1791k         62    2        -1  = U1_5
#                     1784k         57    1   F    -1  = W0_8
#                     1792k         61    2        -1 != W0_4
#                     1785k         44    1         0 != U0_4
#                     1793k         43    2   F     0  = V0_3
#                     1786k         59    1   F     1  = U4_3
#                     1794k         58    2         0 != U1_7
#  ! Time = 54.24s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1787k         60    1         0 != V5_7
#                     1795k         52    2         0 != W0_0
#                     1788k         44    1        -1 != U2_3
#                     1796k         58    2   F     1 != V3_1
#                     1789k         41    1   F     0  = V2_7
#                     1797k         58    2        -1 != V2_5
#                     1790k         42    1         1  = W1_9
#                     1798k         57    2         1 != U0_10
#                     1791k         40    1         0  = V3_2
#                     1799k         63    2         0 != V0_5
#                     1792k         41    1         0  = V0_3
#                     1793k         53    1         1  = V5_0
#                     1800k         42    2         1  = V0_0
#                     1794k         37    1        -1 != V4_0
#                     1801k         54    2         1 != V0_0
#                     1795k         31    1        -1  = W3_3
#                     1802k         55    2         1  = V3_0
#                     1796k         40    1   F     0 != W1_1
#                     1803k         58    2   F     0  = U1_9
#                     1797k         44    1         1  = V5_0
#  ! Time = 54.59s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1804k         57    2        -1  = W0_4
#                     1798k         29    1        -1  = W2_10
#                     1805k         77    2   F     0 != W2_3
#                     1799k         34    1         0 != V2_7
#                     1806k         82    2   F    -1 != U4_5
#                     1800k         49    1         0 != U5_5
#                     1807k         81    2   F     0 != W2_1
#                     1801k         56    1         0  = W1_8
#                     1808k         80    2        -1  = U3_5
#                     1802k         56    1   F     0  = W2_0
#                     1809k         76    2   F     1  = W2_3
#                     1803k         46    1        -1 != V4_10
#                     1804k         48    1   F     1  = W0_0
#                     1810k         76    2         0  = V2_6
#                     1805k         35    1   F     0 != U0_4
#                     1811k         83    2   F     1  = W2_5
#                     1812k         85    2   F     1  = W2_3
#                     1806k         55    1   F    -1 != V0_10
#                     1813k         65    2         0 != W3_5
#                     1807k         48    1   F    -1 != V4_4
#  ! Time = 54.91s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1814k         67    2         1  = U1_9
#                     1808k         60    1   F    -1  = U2_6
#                     1815k         38    2         1  = V2_6
#                     1809k         54    1   F     0  = U2_3
#                     1816k         60    2   F     0 != W2_0
#                     1810k         67    1        -1 != U2_3
#                     1817k         78    2   F     1 != W3_8
#                     1818k         75    2   F     1  = U3_1
#                     1811k         64    1   F     0  = V4_7
#                     1819k         37    2   F     1 != U1_3
#                     1812k         60    1        -1  = V4_7
#                     1820k         48    2   F     0  = V3_4
#                     1821k         36    2   F    -1  = U2_7
#                     1813k         57    1         1 != U2_3
#                     1822k         35    2         1 != W1_9
#                     1814k         67    1   F    -1  = U2_6
#                     1823k         44    2         0 != V0_2
#                     1824k         64    2        -1  = U0_7
#                     1815k         42    1         1 != V0_1
#                     1816k         44    1         1 != V3_8
#  ! Time = 55.24s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1825k         56    2   F     1  = U1_7
#                     1817k         46    1   F     1 != V4_2
#                     1826k         52    2         1  = V0_7
#                     1818k         17    1   F    -1  = U2_5
#                     1827k         44    2   F    -1 != V1_1
#                     1819k         24    1         0  = V2_6
#                     1828k         30    2   F    -1  = V4_7
#                     1820k         59    1         0 != V0_0
#                     1829k         37    2         1 != U0_1
#                     1821k         62    1   F    -1  = U2_6
#                     1830k         34    2   F    -1  = U1_0
#                     1822k         58    1         0  = V0_4
#                     1831k         29    2         0 != W1_7
#                     1823k         42    1         0 != V5_5
#                     1824k         48    1   F     0 != V5_1
#                     1832k         31    2   F     1 != W1_0
#                     1825k         38    1   F    -1  = U2_1
#                     1833k         46    2        -1  = V0_4
#                     1826k         55    1         0  = V3_5
#                     1834k         56    2   F    -1 != V0_4
#  ! Time = 55.50s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1827k         57    1   F    -1 != V0_9
#                     1835k         40    2   F     1 != V1_9
#                     1828k         44    1        -1  = U5_4
#                     1836k         65    2         0 != U4_5
#                     1829k         46    1         0  = V4_8
#                     1837k         46    2         1  = W3_3
#                     1830k         45    1   F    -1  = U5_1
#                     1838k         45    2         1 != U1_4
#                     1831k         56    1   F     1 != U4_6
#                     1839k         42    2        -1 != V0_5
#                     1832k         52    1         0 != U4_6
#                     1833k         13    1   F     0  = V5_0
#                     1840k         42    2   F     0  = U3_6
#                     1834k          9    1        -1 != V5_1
#                     1841k         53    2         0  = V5_7
#                     1835k         36    1         0 != U2_6
#                     1842k         55    2   F     1 != V5_7
#                     1836k         50    1         1 != V2_5
#                     1837k         44    1   F     0  = U4_2
#                     1843k         57    2         0 != W3_10
#  ! Time = 55.75s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1838k         52    1         0  = W2_3
#                     1844k         62    2   F     0  = U3_8
#                     1839k         58    1         0  = U3_1
#                     1845k         63    2   F     1  = W1_8
#                     1840k         50    1         0  = U0_6
#                     1846k         61    2   F     1 != U4_0
#                     1841k         51    1   F    -1 != W1_5
#                     1847k         61    2         0 != U4_1
#                     1842k         44    1         1 != U3_1
#                     1848k         63    2         0 != V2_0
#                     1843k         38    1   F     1 != V5_6
#                     1849k         63    2   F     0  = V2_0
#                     1844k         67    1        -1  = V4_9
#                     1850k         63    2   F     1  = U1_4
#                     1845k         61    1        -1 != U2_4
#                     1851k         64    2         0 != W1_7
#                     1846k         57    1        -1  = V4_2
#                     1852k         68    2   F    -1  = V0_9
#                     1847k         54    1   F     1  = U2_3
#                     1853k         83    2        -1  = U3_10
#  ! Time = 56.04s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1848k         44    1   F     1 != W2_4
#                     1854k         74    2   F    -1 != U0_7
#                     1855k         72    2   F    -1 != U3_4
#                     1849k         45    1         1  = W0_0
#                     1856k         81    2         1  = U0_4
#                     1850k         50    1        -1  = V4_10
#                     1857k         64    2   F     0  = V2_3
#                     1851k         48    1         1  = W1_6
#                     1858k         53    2         1 != V3_4
#                     1852k         45    1   F     1 != U1_1
#                     1859k         47    2         0  = V0_1
#                     1853k         63    1   F     0  = W1_4
#                     1854k         44    1         1 != U2_4
#                     1860k         40    2   F     1  = W3_3
#                     1861k         38    2         0 != W2_5
#                     1855k         54    1   F     0  = U4_2
#                     1862k         38    2   F    -1  = V1_10
#                     1856k         58    1        -1  = W2_0
#                     1863k         36    2   F     1 != W1_6
#                     1857k         57    1   F     1 != W0_3
#  ! Time = 56.38s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1864k         33    2   F     0 != V3_0
#                     1858k         65    1         1  = V2_6
#                     1865k         44    2         0  = W3_6
#                     1859k         57    1         0  = W1_8
#                     1866k         42    2        -1 != U2_5
#                     1860k         53    1         1  = V2_5
#                     1867k         40    2         0 != V1_9
#                     1861k         47    1   F     1  = U5_0
#                     1862k         49    1   F     0 != W1_8
#                     1868k         48    2   F     1  = W2_8
#                     1863k         47    1         1  = W3_0
#                     1869k         56    2   F     0  = U1_5
#                     1870k         47    2   F     0  = U3_7
#                     1864k         47    1        -1 != W1_6
#                     1871k         62    2         0  = V0_6
#                     1865k         51    1        -1  = W3_0
#                     1872k         29    2   F     1 != V1_8
#                     1866k         58    1        -1 != W1_7
#                     1873k         46    2   F     1  = W0_3
#                     1867k         55    1   F     0  = W1_6
#  ! Time = 56.66s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1874k         36    2   F     0  = W2_1
#                     1868k         61    1         1 != W2_10
#                     1875k         45    2   F     0  = W0_8
#                     1869k         52    1   F     0  = U4_1
#                     1870k         66    1   F    -1 != U5_8
#                     1876k         57    2   F     1  = V1_3
#                     1871k         64    1         1  = V4_10
#                     1877k         45    2         1  = W1_4
#                     1872k         77    1        -1 != W0_9
#                     1878k         52    2         0 != W1_3
#                     1873k         50    1   F    -1  = W0_10
#                     1879k         55    2         0  = W3_8
#                     1874k         47    1   F     1  = W0_7
#                     1880k         62    2   F     0  = V0_1
#                     1875k         54    1   F     1 != U2_6
#                     1881k         36    2   F     1  = V2_0
#                     1876k         33    1         0 != U3_5
#                     1882k         26    2         0 != W1_8
#                     1877k         39    1   F     0  = W2_9
#                     1883k         54    2         0 != W3_8
#  ! Time = 56.92s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1878k         47    1   F     0  = V0_3
#                     1884k         58    2   F     0 != V0_10
#                     1885k         58    2         0  = U2_7
#                     1879k         62    1         0  = V4_4
#                     1886k         25    2         1 != V0_10
#                     1880k         53    1   F     1  = U4_7
#                     1887k         47    2   F    -1 != U3_5
#                     1881k         63    1         1 != W2_8
#                     1888k         59    2   F     1  = V1_1
#                     1882k         42    1   F     0  = V4_4
#                     1883k         30    1        -1  = U5_4
#                     1889k         25    2   F    -1  = W3_6
#                     1890k         73    2         0  = W1_4
#                     1884k         47    1   F    -1 != V2_0
#                     1891k         70    2   F    -1  = U1_3
#                     1885k         43    1   F     0  = W0_1
#                     1892k         47    2   F     1 != W3_8
#                     1886k         49    1         0  = U1_2
#                     1893k         60    2         1 != W2_2
#                     1894k         55    2         0  = U1_3
#  ! Time = 57.24s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1887k         19    1         0  = W3_0
#                     1895k         47    2   F     1 != V0_9
#                     1888k         19    1         0  = W1_7
#                     1896k         42    2   F    -1  = U0_5
#                     1889k         33    1   F     1  = U4_2
#                     1897k         33    2   F    -1 != V5_10
#                     1890k         39    1         1  = W3_0
#                     1898k         57    2         1 != V5_0
#                     1891k         24    1         1  = V0_9
#                     1899k         45    2   F     1 != V0_5
#                     1892k         59    1   F     1  = U0_10
#                     1900k         17    2         0 != V1_10
#                     1901k         54    2         1  = W1_4
#                     1893k         71    1   F    -1 != U2_2
#                     1902k         49    2         1  = V0_5
#                     1894k         54    1   F     1  = U1_3
#                     1903k         33    2         1 != V0_5
#                     1895k         46    1   F     1  = V2_4
#                     1904k         39    2         0  = V0_7
#                     1896k         29    1   F    -1  = U2_4
#  ! Time = 57.50s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1905k         40    2         0  = V5_10
#                     1897k         49    1   F    -1 != U4_4
#                     1906k         38    2   F     1  = W1_4
#                     1907k         38    2         0 != V1_4
#                     1898k         47    1   F    -1  = W1_8
#                     1908k         33    2         0  = V2_8
#                     1899k         51    1         0  = V2_3
#                     1909k         29    2        -1  = U0_10
#                     1910k         44    2         1  = V5_10
#                     1900k         56    1   F     0 != V5_5
#                     1911k         45    2         0 != W0_8
#                     1912k         54    2         0 != W0_6
#                     1901k         52    1         0  = U0_5
#                     1913k         56    2         1  = U3_2
#                     1914k         47    2         0 != U3_8
#                     1902k         59    1   F     0 != U0_5
#                     1915k         64    2         0 != V3_0
#                     1916k         59    2        -1 != U0_5
#                     1917k         60    2   F     0  = W3_4
#                     1903k         49    1         0  = V2_10
#  ! Time = 57.80s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1918k         70    2   F    -1  = W1_4
#                     1919k         54    2   F     1 != V1_9
#                     1904k         46    1   F     1  = U5_2
#                     1920k         53    2         0 != W2_3
#                     1921k         62    2         1 != V3_2
#                     1905k         56    1         0 != U0_5
#                     1922k         72    2         0  = U0_10
#                     1923k         30    2   F     1 != U4_5
#                     1906k         60    1   F     0  = V5_8
#                     1924k         70    2   F    -1  = V1_4
#                     1925k         70    2   F    -1  = V1_9
#                     1907k         53    1         0  = U4_8
#                     1926k         55    2         0  = U4_5
#                     1908k          7    1   F     0  = V0_8
#                     1927k         41    2   F     1  = U2_7
#                     1909k         34    1         0 != U3_1
#                     1928k         59    2   F     0 != U0_4
#                     1910k         53    1   F     0  = W0_0
#                     1929k         58    2         0  = W0_6
#                     1911k         67    1         1 != V0_7
#  ! Time = 58.09s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1930k         55    2         1  = W3_9
#                     1912k         19    1         1 != U3_2
#                     1931k         44    2   F     0 != V1_7
#                     1913k         75    1   F     1  = U5_10
#                     1932k         77    2         0  = W3_10
#                     1914k         69    1        -1  = W3_0
#                     1933k         38    2         0 != W1_8
#                     1915k         55    1   F    -1 != U3_8
#                     1934k         66    2        -1  = V0_5
#                     1916k         49    1        -1 != V2_6
#                     1935k         66    2   F    -1 != V0_8
#                     1917k         57    1   F    -1 != V4_9
#                     1936k         35    2   F     1  = U3_0
#                     1918k         75    1   F     1  = W0_2
#                     1937k         53    2         0  = W3_3
#                     1938k         47    2   F    -1 != W3_0
#                     1919k         60    1   F    -1 != U1_0
#                     1939k         25    2   F    -1  = V3_7
#                     1920k         58    1   F     0 != W3_0
#                     1940k         65    2   F    -1 != U4_10
#  ! Time = 58.34s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1921k         78    1   F     1  = W3_3
#                     1941k         54    2        -1  = W3_10
#                     1922k         59    1         0 != U1_9
#                     1942k         58    2   F    -1 != U1_7
#                     1923k         68    1         1  = U1_2
#                     1943k         45    2         1  = U0_6
#                     1924k         65    1   F    -1  = V4_3
#                     1925k         60    1   F     0  = U1_6
#                     1944k         57    2        -1 != W1_1
#                     1926k         58    1         0  = V5_9
#                     1945k         53    2   F     0  = W2_4
#                     1927k         64    1   F     0  = U1_9
#                     1946k         48    2         0 != U1_8
#                     1928k         51    1   F     1 != V4_5
#                     1947k         51    2   F    -1  = W0_2
#                     1929k         28    1   F     0  = V4_2
#                     1948k         53    2         1  = W3_8
#                     1930k         28    1         1 != W2_5
#                     1949k         53    2   F    -1 != V3_4
#                     1931k         28    1   F     1 != W1_7
#  ! Time = 58.66s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1950k         61    2         0 != V3_5
#                     1932k         44    1   F    -1 != U2_8
#                     1951k         68    2   F    -1 != W3_2
#                     1933k         28    1         1 != V4_4
#                     1952k         82    2   F     0  = U0_9
#                     1934k         59    1   F     0  = U4_7
#                     1953k         46    2         0  = V0_7
#                     1935k         27    1         0 != U5_8
#                     1954k         71    2         1  = V0_5
#                     1936k         27    1   F     1 != U0_1
#                     1955k         57    2         0 != V3_2
#                     1937k         29    1         0  = U1_3
#                     1956k         40    2   F     1 != U0_10
#                     1938k         70    1   F     1  = V4_4
#                     1939k         67    1        -1 != V0_1
#                     1957k         58    2   F     0 != U4_8
#                     1940k         37    1   F     1 != V5_8
#                     1958k         68    2   F     0 != U1_4
#                     1941k         27    1   F     0  = V3_1
#                     1942k         62    1   F     0  = W0_1
#  ! Time = 59.01s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1959k         68    2   F     0 != U4_1
#                     1943k         27    1         0  = U1_2
#                     1960k         76    2         0  = U4_1
#                     1944k         59    1         1 != U2_4
#                     1961k         45    2   F    -1 != U1_2
#                     1962k         50    2         0 != W0_4
#                     1945k         26    1         1  = U1_10
#                     1946k         39    1         0 != V2_4
#                     1963k         48    2   F    -1 != V2_2
#                     1947k         64    1         1 != V3_5
#                     1964k         54    2         1  = W3_10
#                     1965k         47    2   F     1  = V5_0
#                     1948k         44    1   F     0  = V2_6
#                     1949k         58    1         0 != U1_0
#                     1966k         67    2         0 != U1_8
#                     1950k         54    1        -1  = V0_2
#                     1967k         76    2         1 != W1_3
#                     1951k         50    1   F     1 != V5_5
#                     1968k         71    2        -1  = U0_1
#                     1952k         52    1   F     1  = V2_9
#  ! Time = 59.36s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1969k         74    2         0 != W2_7
#                     1953k         64    1   F     0  = U5_7
#                     1970k         76    2         0 != W1_5
#                     1954k         55    1         0  = W0_9
#                     1971k         56    2   F     1  = U1_0
#                     1955k         66    1   F     0 != U4_2
#                     1972k         56    2   F     0  = U3_9
#                     1956k         35    1   F     1  = W2_4
#                     1973k         57    2         0  = W2_3
#                     1957k         55    1         0  = W2_0
#                     1974k         47    2         0  = U1_8
#                     1958k         49    1         0 != U2_8
#                     1975k         52    2   F     1 != V1_8
#                     1959k         63    1        -1  = W0_10
#                     1976k         56    2         1 != V0_1
#                     1960k         63    1   F     0  = V4_6
#                     1977k         67    2         1  = W3_1
#                     1961k         28    1   F     1 != V5_9
#                     1978k         63    2         0 != U4_7
#                     1962k         34    1        -1  = V2_3
#  ! Time = 59.63s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1979k         67    2   F     0 != U4_4
#                     1963k         42    1         0 != U4_6
#                     1980k         62    2         0 != V5_10
#                     1964k         77    1         1  = U5_0
#                     1981k         57    2        -1  = U4_9
#                     1965k         69    1         1 != U1_3
#                     1982k         47    2   F     1  = U4_10
#                     1966k         70    1        -1 != U5_7
#                     1983k         59    2   F    -1 != W2_2
#                     1967k         66    1         0  = U2_5
#                     1984k         60    2        -1  = V3_0
#                     1968k         58    1   F     1  = V3_8
#                     1985k         39    2         1  = V2_8
#                     1986k         45    2   F     0 != V5_2
#                     1969k         30    1   F     0  = U5_5
#                     1970k         50    1   F    -1  = W3_3
#                     1987k         55    2        -1 != V2_9
#                     1971k         59    1   F     1  = U5_1
#                     1988k         56    2         0  = V5_6
#                     1972k         54    1   F     1 != V3_4
#  ! Time = 59.94s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1989k         56    2   F     0  = V5_9
#                     1973k         41    1   F     1  = V3_5
#                     1990k         55    2   F     1 != V5_8
#                     1974k         58    1         0 != V4_0
#                     1991k         55    2         1  = W1_1
#                     1975k         53    1         1 != W3_5
#                     1992k         54    2   F     0 != V5_2
#                     1976k         32    1   F     1 != V2_2
#                     1993k         56    2         0 != V2_6
#                     1977k         35    1   F     0  = V0_8
#                     1994k         56    2         1  = V3_5
#                     1978k         46    1         0 != U2_10
#                     1995k         77    2         1  = U3_0
#                     1979k         54    1         1 != U1_9
#                     1996k         44    2   F    -1 != U4_4
#                     1997k         55    2   F     1 != W2_2
#                     1980k         34    1   F     0 != V3_5
#                     1998k         71    2   F     1 != V2_6
#                     1981k         41    1   F    -1 != V4_7
#                     1999k         53    2   F     1  = W2_5
#  ! Time = 60.23s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2000k         68    2         0 != V3_5
#                     1982k         27    1        -1 != V0_7
#                     1983k         49    1   F    -1 != U0_6
#                     2001k         72    2         1  = U4_5
#                     2002k         67    2   F    -1  = U3_4
#                     1984k         46    1         0 != U1_3
#                     2003k         68    2        -1 != V3_8
#                     2004k         76    2   F     1  = U0_3
#                     1985k         41    1        -1 != V2_6
#                     2005k         73    2   F     0  = U3_9
#                     2006k         67    2   F     1 != U4_5
#                     1986k         45    1        -1  = U0_6
#                     2007k         72    2         0 != U0_0
#                     2008k         61    2        -1 != V2_8
#                     1987k         55    1   F    -1  = W2_10
#                     2009k         40    2        -1  = U1_1
#                     1988k         44    1   F     1  = W2_7
#                     2010k         46    2   F    -1 != V2_7
#                     1989k         40    1         0  = U1_1
#                     2011k         69    2   F    -1  = W2_7
#  ! Time = 60.59s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     1990k         32    1   F     0  = V5_9
#                     2012k         39    2   F     0  = V2_0
#                     1991k         52    1         0  = U0_1
#                     2013k         77    2   F    -1 != U0_8
#                     1992k         57    1         0  = V5_4
#                     2014k         77    2   F     0  = U4_7
#                     1993k         26    1   F     1 != V2_4
#                     2015k         76    2   F    -1  = V1_10
#                     1994k         38    1   F     0  = U5_6
#                     2016k         70    2   F    -1 != U4_9
#                     1995k         44    1   F     0  = W3_1
#                     2017k         34    2   F     0  = V3_9
#                     1996k         14    1         1 != V0_1
#                     2018k         42    2        -1  = U0_5
#                     1997k         73    1         1 != V5_0
#                     2019k         46    2        -1  = W3_10
#                     1998k         82    1        -1 != W1_3
#                     1999k         56    1        -1  = U4_6
#                     2020k         58    2   F     0  = W1_0
#                     2000k         70    1   F     1  = U5_0
#  ! Time = 60.84s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2021k         45    2   F     1  = W0_2
#                     2022k         61    2   F     0 != V1_2
#                     2001k         66    1   F     0  = V2_2
#                     2023k         41    2   F     1  = U0_4
#                     2002k         58    1         0  = W0_9
#                     2024k         67    2   F     1 != U4_8
#                     2003k         71    1         1  = W3_1
#                     2025k         49    2   F     0 != U0_8
#                     2004k         69    1        -1 != U1_10
#                     2026k         25    2   F     1  = U4_7
#                     2005k         61    1   F     1 != V4_8
#                     2027k         45    2         0  = U4_4
#                     2006k         60    1   F     0  = U1_2
#                     2028k         29    2   F     0  = U4_10
#                     2007k         44    1   F    -1 != W2_10
#                     2029k         44    2         0 != W3_1
#                     2008k         58    1   F    -1 != U2_10
#                     2030k         42    2         1  = V1_5
#                     2009k         75    1         0  = U4_1
#                     2031k         56    2   F    -1  = W1_4
#  ! Time = 61.19s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2010k         55    1         0 != U5_5
#                     2032k         25    2         1  = W1_6
#                     2011k         61    1        -1 != V3_6
#                     2033k         29    2   F    -1 != U3_0
#                     2012k         56    1   F     1 != W0_9
#                     2034k         25    2         0  = V5_3
#                     2013k         65    1   F    -1  = U2_5
#                     2035k         47    2   F     0  = V2_7
#                     2014k         42    1   F     0 != V0_10
#                     2036k         50    2        -1  = W3_9
#                     2015k         70    1   F    -1 != V2_10
#                     2016k         70    1         0  = U0_10
#                     2037k         51    2   F     0 != U1_1
#                     2017k         83    1         0  = U5_5
#                     2038k         37    2        -1  = W1_4
#                     2018k         55    1        -1  = U0_2
#                     2019k         66    1   F     0  = V0_4
#                     2039k         38    2        -1  = W3_1
#                     2020k         55    1   F     0  = U5_10
#                     2021k         60    1         0 != V3_5
#  ! Time = 61.50s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2040k         49    2   F     0  = V0_0
#                     2041k         54    2   F    -1 != W3_4
#                     2022k         71    1   F     0 != V2_3
#                     2023k         68    1         0  = V4_4
#                     2042k         61    2   F     0  = V3_6
#                     2024k         99    1   F     1 != W2_6
#                     2043k         46    2   F     0  = V2_0
#                     2025k         95    1   F     1 != W2_6
#                     2044k         52    2   F     1  = U0_10
#                     2026k         27    1         1 != V5_9
#                     2045k         47    2         1 != V3_9
#                     2027k         23    1   F     1  = U5_9
#                     2046k         48    2   F    -1 != V3_10
#                     2028k         32    1   F    -1 != U5_9
#                     2029k         32    1   F    -1  = U4_2
#                     2047k         52    2         1  = V2_2
#                     2030k         34    1   F     0  = V5_9
#                     2048k         49    2   F     0  = V2_1
#                     2031k         34    1   F     0  = W3_9
#                     2032k         32    1   F     0  = W3_1
#  ! Time = 61.80s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2049k         46    2   F     1  = V0_0
#                     2033k         33    1   F    -1  = U5_9
#                     2050k         59    2        -1 != V0_0
#                     2034k         31    1   F     1 != V5_9
#                     2035k         33    1        -1 != V0_7
#                     2051k         46    2   F     0 != U1_1
#                     2052k         52    2   F     1  = W0_2
#                     2053k         62    2         1  = V0_1
#                     2036k         51    1         1  = V0_7
#                     2054k         29    2         0  = V2_8
#                     2055k         60    2         0 != V5_5
#                     2037k         59    1   F    -1  = V3_5
#                     2056k         51    2         0  = V5_0
#                     2057k         41    2         0  = V0_8
#                     2038k         52    1         0 != U0_4
#                     2058k         67    2         0 != U4_5
#                     2059k         28    2         0  = V5_0
#                     2039k         53    1   F    -1  = W0_7
#                     2060k         53    2   F     1 != W0_2
#                     2061k         60    2   F     0 != W1_4
#  ! Time = 62.11s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2040k         58    1   F     0  = U1_6
#                     2062k         56    2   F     0  = W0_9
#                     2063k         49    2         0 != W3_5
#                     2041k         55    1   F     0  = V0_8
#                     2064k         43    2   F     0  = U0_4
#                     2065k         57    2   F    -1 != V1_5
#                     2066k         39    2         0  = W0_5
#                     2042k         53    1   F    -1 != W0_5
#                     2067k         45    2         1 != U4_9
#                     2068k         42    2         0 != V5_7
#                     2043k         53    1        -1 != V2_7
#                     2069k         49    2   F     0  = V0_9
#                     2070k         61    2   F    -1 != V4_9
#                     2044k         57    1   F    -1  = U3_2
#                     2071k         45    2   F     1  = W3_4
#                     2072k         45    2   F     1  = V1_2
#                     2045k         59    1         0 != U2_6
#                     2073k         59    2   F     0  = U0_0
#                     2074k         39    2         0 != U3_3
#                     2046k         58    1         1 != W1_3
#  ! Time = 62.42s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2075k         34    2         0 != V3_0
#                     2047k         78    1         0  = W2_4
#                     2076k         55    2         1 != V2_8
#                     2048k         69    1         1 != U0_7
#                     2077k         46    2   F     0  = V5_7
#                     2049k         61    1   F     0 != V0_10
#                     2078k         46    2        -1 != U4_8
#                     2050k         47    1         0  = V0_2
#                     2079k         41    2        -1 != U4_8
#                     2051k         47    1   F     0  = W2_3
#                     2080k         56    2   F     0  = V0_1
#                     2052k         69    1   F    -1  = W2_5
#                     2081k         38    2   F    -1  = V4_9
#                     2053k         53    1        -1 != U4_4
#                     2082k         49    2        -1 != U1_5
#                     2054k         36    1   F     1  = U4_7
#                     2083k         54    2         0 != W3_8
#                     2055k         22    1   F     0  = W0_2
#                     2084k         60    2         0  = V4_9
#                     2056k         63    1         1 != W2_6
#  ! Time = 62.67s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2085k         46    2   F     1  = U4_9
#                     2057k         56    1   F     0  = W3_9
#                     2086k         30    2   F     0  = V1_0
#                     2058k         61    1   F    -1  = V4_10
#                     2087k         41    2   F     1 != V2_9
#                     2059k         39    1   F     0  = W0_1
#                     2088k         56    2         0  = W2_8
#                     2060k         54    1   F    -1 != U4_7
#                     2089k         56    2   F     1 != V3_3
#                     2061k         53    1         0  = W3_6
#                     2090k         60    2         1  = V5_9
#                     2062k         70    1   F    -1  = V4_3
#                     2091k         68    2         0  = U1_6
#                     2063k         72    1         0  = V2_0
#                     2092k         59    2         1 != U4_2
#                     2064k         42    1         1 != U0_10
#                     2093k         47    2   F     1 != U1_0
#                     2065k         66    1         0 != V2_2
#                     2094k         57    2         0 != V1_6
#                     2095k         50    2         0  = U0_3
#  ! Time = 62.94s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2066k         44    1   F    -1  = V4_10
#                     2096k         51    2   F     0  = V1_1
#                     2067k         55    1   F    -1  = W2_6
#                     2068k         42    1        -1 != V4_1
#                     2097k         53    2         0 != W1_6
#                     2069k         40    1        -1 != U2_0
#                     2098k          8    2   F    -1 != V3_8
#                     2070k         46    1   F     0 != U4_3
#                     2099k         19    2        -1 != W0_10
#                     2071k         47    1         0 != U5_2
#                     2072k         47    1         0 != V2_2
#                     2100k         27    2   F     0 != U0_1
#                     2073k         44    1         0  = U4_10
#                     2101k         12    2         0 != U0_2
#                     2074k         70    1   F     1 != W0_7
#                     2102k         50    2   F     0  = W0_4
#                     2075k         58    1         0  = U1_6
#                     2103k         39    2         1 != V1_3
#                     2104k         64    2   F     0  = V3_5
#                     2076k         44    1   F    -1 != W3_2
#  ! Time = 63.29s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2105k         60    2         0  = V1_6
#                     2077k         40    1        -1  = V0_6
#                     2106k         51    2        -1  = V0_2
#                     2078k         63    1   F    -1  = U4_7
#                     2107k         61    2   F     0  = U3_9
#                     2079k         56    1   F    -1 != W2_5
#                     2108k         51    2   F     1 != W2_2
#                     2080k         77    1         1  = U5_0
#                     2109k         53    2         0 != V3_4
#                     2081k         84    1   F     1 != V4_0
#                     2110k         63    2   F     1  = V3_3
#                     2111k         71    2         0 != U3_6
#                     2082k         81    1   F     0  = V0_0
#                     2112k         63    2         0  = V5_0
#                     2083k         79    1   F    -1  = W2_5
#                     2113k         47    2   F     0  = V1_6
#                     2114k         43    2   F     0  = W0_7
#                     2084k         79    1   F    -1  = V4_10
#                     2115k         59    2   F     0 != V3_7
#                     2085k         75    1   F    -1  = W3_10
#  ! Time = 63.66s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2116k         62    2        -1 != V1_7
#                     2117k         66    2   F     1  = U3_9
#                     2086k         45    1         1 != W1_7
#                     2118k         66    2   F     1  = W1_4
#                     2087k         31    1   F     1  = V2_3
#                     2119k         76    2        -1  = U1_8
#                     2088k         62    1   F     1 != V2_3
#                     2120k         47    2         0  = U3_0
#                     2121k         65    2   F     0  = W0_4
#                     2089k         59    1   F     0  = U5_5
#                     2122k         69    2         0  = W3_2
#                     2090k         62    1   F     1  = V4_0
#                     2123k         64    2         0  = W3_1
#                     2091k         51    1   F     1 != U2_5
#                     2124k         70    2         1  = U1_1
#                     2092k         48    1   F     1  = V4_5
#                     2125k         45    2   F     0 != W3_10
#                     2093k         53    1   F     1  = U4_7
#                     2126k         52    2   F    -1  = V3_8
#                     2094k         63    1   F    -1 != W2_3
#  ! Time = 63.98s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2127k         57    2   F    -1 != V3_3
#                     2095k         62    1         1 != U5_0
#                     2128k         65    2   F    -1 != U4_5
#                     2096k         50    1   F     1  = V2_5
#                     2129k         83    2   F     0  = W2_3
#                     2097k         64    1   F     1 != U4_4
#                     2098k         63    1         0  = V5_8
#                     2130k         85    2         1 != V1_6
#                     2131k         93    2         1  = U4_5
#                     2099k         62    1         1 != V1_4
#                     2132k         62    2         0  = U0_10
#                     2100k         61    1        -1  = V2_3
#                     2133k         45    2   F     0 != W3_3
#                     2101k         65    1   F    -1  = U4_0
#                     2134k         58    2         1  = W1_9
#                     2102k         64    1         0  = W0_5
#                     2135k         39    2         0 != W0_5
#                     2103k         41    1         0  = U2_1
#                     2136k         73    2   F     0  = V2_0
#                     2104k         55    1   F     0  = W0_8
#  ! Time = 64.34s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2137k         67    2   F     0  = W0_6
#                     2105k         70    1         0 != U4_1
#                     2138k         57    2   F    -1 != V5_10
#                     2106k         46    1   F     1  = U2_8
#                     2139k         67    2   F     0  = V2_5
#                     2107k         33    1   F     0  = W2_9
#                     2140k         10    2   F     0  = V2_1
#                     2108k         72    1   F     1 != V0_1
#                     2141k         39    2   F     1  = V3_2
#                     2109k         42    1   F    -1  = U0_1
#                     2142k         13    2         0  = V0_6
#                     2110k         63    1         1  = V2_9
#                     2143k         68    2         0  = V1_2
#                     2111k         37    1   F    -1 != V0_4
#                     2144k         11    2         1  = U1_6
#                     2112k         48    1         0 != W2_8
#                     2145k         72    2         0 != W0_6
#                     2113k         55    1   F     1  = W0_6
#                     2146k         76    2         0 != W1_6
#                     2114k         45    1   F    -1 != W2_10
#  ! Time = 64.61s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2147k         70    2         0  = V1_6
#                     2115k         36    1   F     1 != V1_0
#                     2148k         70    2        -1  = V3_5
#                     2116k         19    1   F     1  = U1_6
#                     2149k         66    2   F     1 != W2_6
#                     2117k         63    1   F     0  = W0_0
#                     2150k         69    2         0 != W0_10
#                     2118k         52    1   F     0  = V0_3
#                     2151k         63    2   F     1  = W2_10
#                     2119k         57    1   F    -1  = U2_5
#                     2152k         48    2   F    -1  = U3_7
#                     2120k         58    1   F     0  = W3_0
#                     2153k         51    2         0  = U3_7
#                     2121k         74    1         0  = V2_3
#                     2154k         66    2         0  = V2_10
#                     2122k         66    1   F     0  = W2_3
#                     2155k         71    2         0  = V2_2
#                     2123k         39    1   F    -1 != V5_5
#                     2156k         58    2   F     1 != U4_3
#                     2124k         27    1         0 != U0_4
#  ! Time = 64.90s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     2157k         63    2   F     1  = U4_9
#                     2125k         38    1   F    -1  = U1_1
#                     2158k         58    2         0  = V3_4
#                     2126k         28    1         0  = W2_9
#                     2159k         77    2         0  = V2_6
#                     2127k         25    1         0  = U4_6
#                     2160k         70    2        -1  = V3_2
#                     2128k         28    1   F     1  = V5_4
#                     2161k         56    2         0 != U1_2
#                     2129k         37    1   F    -1 != W2_8
#                     2162k         53    2         0  = W2_5
#                     2130k         36    1         0 != W0_7
#                     2131k         54    1   F     1  = U1_7
#                     2163k         65    2         0 != U0_0
#                     2132k         49    1         1 != U1_3
#                     2164k         48    2   F    -1  = V3_5
#                     2133k         55    1         0  = W0_2
#                     2165k         61    2        -1 != W2_2
# ...
#                     3953k         57    1         1  = V2_6
#                     3907k         66    2   F     0 != U4_10
#  ! Time = 122.34s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     3954k         53    1   F    -1  = W2_3
#                     3908k         69    2   F     1  = U4_10
#                     3955k         49    1   F    -1  = V3_8
#                     3956k         10    1   F    -1  = U2_4
#                     3909k         60    2   F     1 != V3_3
#                     3957k         37    1   F    -1 != U0_8
#                     3910k         46    2   F    -1  = U4_0
#                     3958k         57    1        -1  = U2_10
#                     3959k         49    1   F     0 != U2_1
#                     3911k         56    2         0 != W3_4
#                     3960k         55    1   F     1  = W0_6
#                     3912k         63    2         1 != V5_3
#                     3913k         66    2         0  = U4_0
#                     3961k         37    1         0  = V3_2
#                     3914k         50    2   F    -1  = U1_10
#                     3962k         64    1         1 != U2_7
#                     3963k         36    1   F     1 != V5_8
#                     3915k         46    2   F     1  = V5_3
#                     3964k         67    1        -1  = W2_0
#                     3916k         62    2   F     1  = V3_5
#  ! Time = 122.63s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     3965k         55    1         0  = V0_7
#                     3966k         71    1         1  = U4_7
#                     3917k         63    2   F    -1 != V5_3
#                     3967k         72    1   F    -1  = W2_6
#                     3918k         61    2   F     1 != U1_0
#                     3968k         59    1   F    -1  = V5_6
#                     3919k         64    2   F     1  = V3_0
#                     3969k         67    1        -1 != W3_0
#                     3970k         63    1   F    -1 != W0_7
#                     3920k         29    2   F     0  = V2_6
#                     3971k         63    1        -1 != V5_6
#                     3921k          5    2         1 != V2_4
#                     3972k         61    1   F    -1 != V5_5
#                     3922k          7    2        -1  = U0_5
#                     3973k         50    1         1  = V3_2
#                     3923k         22    2   F     0  = U1_8
#                     3974k         57    1   F     1  = U2_4
#                     3924k          7    2   F     1 != U1_5
#                     3975k         64    1   F     0 != V4_8
#                     3976k         61    1         0 != W3_0
#  ! Time = 122.96s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     3925k         14    2        -1  = U1_5
#                     3977k         51    1         0 != U5_10
#                     3926k          9    2         0 != V0_6
#                     3978k         58    1   F    -1  = V5_4
#                     3927k         22    2   F    -1  = V1_6
#                     3979k         54    1   F     1  = U1_7
#                     3928k         14    2   F     1 != V3_10
#                     3980k         53    1   F     0 != U3_6
#                     3929k         19    2         0  = V5_7
#                     3981k         53    1         1 != U3_10
#                     3930k         47    2   F     0  = U5_4
#                     3982k         54    1   F     0  = W2_3
#                     3931k         27    2        -1 != U5_1
#                     3983k         49    1        -1  = V1_4
#                     3932k         39    2   F     1 != V3_1
#                     3933k         49    2   F     0  = U0_10
#                     3984k         59    1         0 != U3_5
#                     3934k         45    2   F     0  = V2_5
#                     3985k         58    1         0  = W2_0
#                     3986k         45    1   F     1 != U5_4
#  ! Time = 123.28s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     3935k          7    2         1  = V0_5
#                     3987k         31    1        -1  = U2_10
#                     3936k         40    2   F    -1 != W0_2
#                     3988k         64    1   F    -1  = W2_2
#                     3937k         11    2   F     1  = W1_1
#                     3989k         52    1         1 != U3_3
#                     3938k         38    2   F     0  = W1_10
#                     3990k         47    1   F     1  = U1_7
#                     3939k         43    2   F     1  = V2_6
#                     3991k         73    1   F     1  = W0_4
#                     3940k         45    2         0 != W2_3
#                     3992k         45    1         0 != V5_0
#                     3941k         33    2         0 != W1_5
#                     3993k         60    1        -1  = W0_3
#                     3942k         33    2         0 != U3_5
#                     3994k         62    1   F     1  = U1_9
#                     3943k         14    2   F     1  = W2_10
#                     3995k         72    1   F     0  = U2_3
#                     3944k         24    2   F     0  = W3_6
#                     3996k         54    1         1  = W1_5
#  ! Time = 123.55s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     3945k         44    2         0  = V1_5
#                     3997k         46    1        -1 != U5_4
#                     3946k          6    2        -1  = W2_9
#                     3998k         45    1        -1  = U2_2
#                     3947k         45    2         0  = U0_7
#                     3999k         49    1   F     1 != W1_5
#                     3948k         25    2   F     1 != U3_8
#                     4000k         54    1   F    -1  = W1_8
#                     3949k          5    2   F     1 != V2_8
#                     4001k         52    1         1 != W2_3
#                     3950k         43    2   F     1  = W3_5
#                     4002k         70    1         0 != U2_7
#                     3951k         31    2   F    -1 != U0_8
#                     4003k         67    1   F     1  = U1_2
#                     3952k         19    2   F    -1  = U0_0
#                     4004k         64    1   F     0  = U5_0
#                     3953k          5    2         0  = U0_9
#                     4005k         37    1         0 != U5_7
#                     3954k         32    2   F     1  = W3_3
#                     4006k         41    1         0  = W0_1
#  ! Time = 123.83s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     3955k         21    2   F     1  = V5_6
#                     4007k         54    1         0 != V0_8
#                     3956k          6    2        -1 != W3_6
#                     4008k         37    1   F     0  = W3_6
#                     3957k         34    2        -1 != U1_4
#                     4009k         44    1         0 != V5_2
#                     3958k         36    2   F    -1  = U3_7
#                     4010k         47    1        -1 != U2_10
#                     3959k         43    2   F    -1 != W2_3
#                     4011k         36    1         0  = V5_0
#                     3960k         59    2         0 != V1_6
#                     4012k         64    1   F    -1 != W2_2
#                     3961k         31    2   F     1  = U2_10
#                     4013k         73    1   F    -1  = V0_10
#                     3962k         32    2         1  = U5_2
#                     4014k         59    1   F     0  = U2_9
#                     3963k         48    2         1 != V5_5
#                     4015k         60    1         0  = W0_6
#                     3964k         57    2         1 != U0_3
#                     4016k         67    1   F     0  = U2_6
#  ! Time = 124.12s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     3965k         34    2         0  = W1_2
#                     4017k         70    1        -1  = W3_5
#                     3966k         44    2        -1 != U0_2
#                     3967k         27    2         1  = V2_5
#                     4018k         56    1         0  = V0_9
#                     3968k         32    2        -1  = U0_8
#                     4019k         56    1         1  = V0_3
#                     3969k         40    2   F     1 != V5_3
#                     4020k         60    1   F     0 != U3_0
#                     3970k         47    2         1 != V2_9
#                     4021k         84    1   F     0 != U3_10
#                     3971k         43    2         0 != V5_8
#                     4022k         54    1         0 != U1_5
#                     3972k         31    2         0 != W2_0
#                     4023k         66    1         0  = V4_5
#                     3973k         71    2        -1  = V2_1
#                     3974k         65    2         0  = W3_6
#                     4024k         47    1        -1 != U5_7
#                     3975k         62    2         0 != V5_10
#                     4025k         83    1   F    -1 != U5_6
#  ! Time = 124.41s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     3976k         65    2         0  = V5_7
#                     4026k         87    1         0  = W1_9
#                     3977k         68    2         1 != U4_1
#                     4027k         76    1         0  = U3_5
#                     3978k         72    2   F     1  = V5_5
#                     4028k         49    1   F     0  = V5_5
#                     3979k         78    2   F    -1  = W1_6
#                     4029k         49    1   F    -1  = V3_6
#                     3980k         67    2        -1  = U3_0
#                     4030k         52    1   F     0 != U2_5
#                     3981k         73    2   F     0  = W1_2
#                     4031k         81    1         1  = W1_9
#                     3982k         50    2         0  = V1_8
#                     4032k         82    1   F     0 != U2_5
#                     3983k         62    2         0 != V1_3
#                     4033k         81    1        -1  = U2_5
#                     3984k         40    2         0 != W0_6
#                     4034k         67    1   F    -1  = V3_6
#                     3985k         49    2         0 != U0_2
#                     4035k         67    1   F    -1 != W1_5
#  ! Time = 124.69s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     3986k         64    2         0 != W2_1
#                     4036k         67    1   F    -1 != U2_5
#                     3987k         66    2         1 != U3_6
#                     3988k         50    2   F     0 != U5_4
#                     4037k         59    1   F    -1 != U1_5
#                     3989k         48    2   F     1 != W3_8
#                     4038k         62    1         0 != U1_5
#                     3990k         73    2   F    -1  = V2_8
#                     4039k         68    1         0 != W1_8
#                     3991k         60    2   F     1 != U0_3
#                     4040k         73    1        -1  = V5_5
#                     3992k         65    2   F     0  = U1_6
#                     4041k         53    1   F     0 != W2_2
#                     3993k         63    2        -1 != W2_2
#                     4042k         19    1         0 != U3_8
#                     3994k         40    2         0 != U2_10
#                     4043k         38    1   F     0  = W0_8
#                     3995k         54    2        -1 != W2_2
#                     4044k         71    1         0 != U1_6
#                     3996k         68    2         1 != U1_8
#  ! Time = 124.96s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     4045k         55    1   F     1  = U2_3
#                     3997k         68    2        -1 != W0_7
#                     4046k         55    1         0 != W3_0
#                     3998k         71    2         0  = U4_3
#                     4047k         36    1        -1  = W2_10
#                     3999k         79    2         0 != V2_10
#                     4048k         37    1         1  = V5_8
#                     4000k         61    2         1 != W1_0
#                     4049k         43    1   F     1 != V3_8
#                     4001k         44    2         1  = U3_4
#                     4050k         40    1         1  = U1_10
#                     4002k         62    2   F     0  = U0_2
#                     4051k         34    1         0  = U1_7
#                     4003k         47    2   F     1  = U1_6
#                     4052k         42    1         1  = W0_4
#                     4004k         62    2   F    -1  = U1_6
#                     4053k         38    1   F    -1 != W1_5
#                     4005k         64    2         1  = W1_8
#                     4054k         50    1   F     0  = V0_6
#                     4006k         54    2   F    -1 != U3_7
#  ! Time = 125.23s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     4007k         49    2        -1 != U5_6
#                     4055k         18    1        -1  = V2_0
#                     4008k         33    2   F     1  = W2_6
#                     4056k         26    1         0 != V0_2
#                     4009k         33    2   F    -1  = V0_8
#                     4057k         53    1   F     0  = V0_9
#                     4010k         34    2        -1  = V3_7
#                     4058k         10    1   F     1  = V4_2
#                     4011k         48    2   F     0  = U1_6
#                     4059k          9    1         0 != W2_5
#                     4012k         51    2         0  = U4_9
#                     4060k         27    1         0  = U1_4
#                     4013k         57    2         0  = W3_0
#                     4061k         32    1        -1  = U5_4
#                     4014k         31    2   F     0  = V5_8
#                     4062k         50    1         0  = U4_3
#                     4015k         31    2   F     1  = W0_2
#                     4063k         45    1   F     0  = U4_8
#                     4016k         37    2         0  = W3_0
#                     4064k         48    1         0  = V5_9
#  ! Time = 125.55s, Memory usage = 4.7 MB
#  !               Branches  Non-fixed    W       Branch decision
#                     4017k         29    2   F     0 != U3_2
#                     4065k         68    1   F    -1  = U1_3
#                     4018k         48    2   F    -1 != V5_10
#                     4066k          4    1   F    -1 != U2_2
#                     4019k         53    2   F     0 != V3_3
#                     4067k         38    1         0 != W0_1
#                     4020k         49    2   F    -1  = W2_3
#                     4068k          9    1        -1 != W0_4
#                     4021k         31    2        -1 != W2_10
#                     4069k         57    1   F     1 != U1_5
#                     4022k         55    2   F     0  = W2_10
#                     4023k         53    2   F     1 != V3_1
#  *                  4069k  125.71s      1         0  = U0_6
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 8094049
#  ! Number of fails        : 3666016
#  ! Total memory usage     : 15.5 MB (15.4 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 125.74s (125.73s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 64381.6
#  ! ----------------------------------------------------------------------------
#
#
#
#
#
#
#
# Holy **** CP got the correct T_n

# %% [markdown]
# # Implementing Symmetry handling per overleaf doc made by Elias

# %%
def CP_opt_symmetry(n,T,R):
    mdl = CpoModel()
    U = [[mdl.integer_var(-1, 1, name="U" + str(n) + "_" + str(r)) for r in range(R)] for n in range(n**2)]
    V = [[mdl.integer_var(-1, 1, name="V" + str(n) + "_" + str(r)) for r in range(R)] for n in range(n**2)]
    W = [[mdl.integer_var(-1, 1, name="W" + str(n) + "_" + str(r)) for r in range(R)] for n in range(n**2)]
    for i in range(n**2):
        for j in range(n**2):
            for k in range(n**2):
                mdl.add(mdl.sum(U[i][r]*V[j][r]*W[k][r] for r in range(R)) == T[i][j][k])

    # Cardinality ordering constraint

    for r in range(R-1):
      mdl.add(
          mdl.sum(mdl.abs(U[i][r]) for i in range(len(U))) + mdl.sum(mdl.abs(V[j][r]) for j in range(len(V)))<=
          mdl.sum(mdl.abs(U[i][r+1]) for i in range(len(U))) + mdl.sum(mdl.abs(V[j][r+1]) for j in range(len(V)))
          )
    
    msol = mdl.solve()
    if msol:
      return [msol,U,V,W]
    else:
      print("Infeasible")
      return -1
